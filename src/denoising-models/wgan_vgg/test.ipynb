# %%
import numpy as np

# %%
history = np.load('save/WGANVGG_loss_27000iter.npy')

# %%
print(history)
# Out:
# [[-7.89467715e-01  8.43056619e-01 -1.19209290e-04  9.97598457e+00]
#  [-7.44826995e-01  7.93354690e-01 -2.04086304e-04  9.97534657e+00]
#  [-8.21109980e-01  8.78001451e-01 -2.80380249e-04  9.97478676e+00]
#  ...
#  [ 3.13017358e+01  7.41992056e-01 -4.34888832e-01  3.90678868e-02]
#  [ 3.09380794e+01  7.33917713e-01 -4.05420303e-01  3.06059122e-02]
#  [ 3.09008821e+01  7.24100709e-01 -4.08430107e-01  3.84156778e-02]]

# %%
import matplotlib.pyplot as plt
plt.plot(history)
