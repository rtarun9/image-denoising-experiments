# %%
import numpy as np

# %%
history = np.load('save/WGANVGG_loss_24000iter.npy')

# %%
print(history)
# Out:
# [[-8.00389558e-01  8.87967229e-01  1.89781189e-04  9.97781086e+00]
#  [-7.44407140e-01  8.25847745e-01  5.34057617e-05  9.97716045e+00]
#  [-7.29127057e-01  8.08921754e-01 -6.38961792e-05  9.97664547e+00]
#  ...
#  [ 4.80223302e+01  8.43163550e-01 -3.22885141e+01  7.29328632e+00]
#  [ 4.78885009e+01  8.38462174e-01 -3.14936824e+01  7.77660131e+00]
#  [ 4.78360513e+01  8.60966384e-01 -3.22565079e+01  7.92991447e+00]]

# %%
import matplotlib.pyplot as plt
plt.plot(history)
